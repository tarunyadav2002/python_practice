# %%
def printString(S, N):
 plaintext = [None] 
 
 
 freq = [0] * 26
 
 
 freqSorted = [None] * 26
 
 
 used = [0] * 26
 
 
 for i in range(N):
 if S[i] != ' ':
 freq[ord(S[i]) - 65] += 1
 
 
 for i in range(26):
 freqSorted[i] = freq[i]
 
 T = "ETAOINSHRDLCUMWFGYPBVKJXQZ"
 
 
 freqSorted.sort(reverse = True)
 
 
 
 for j in range(26):
 if freqSorted[0] == freq[j] and used[j] == 0:
 used[j] = 1
 ch = j
 break
 
 x = ord(T[0]) - 65
 
 
 x = x - ch
 
 
 curr = ""
 
 
 for k in range(N):
 
 
 if S[k] == ' ':
 curr += " "
 continue
 
 
 y = ord(S[k]) - 65
 y += x
 
 if y < 0:
 y += 26
 if y > 25:
 y -= 26
 
 
 curr += chr(y + 65)
 
 plaintext = curr
 
 
 print(plaintext)
S1 = 
"
ljbnqqmjqudtz"
S2 = 
"XLILSYWIMWRSAAJSVWEPIJSVJSYVQMPPMSRHSPPEVWMXMWASVXL
QSVILYVVCFIJSVIXLIWIPPIVVIGIMZIWQSVISJJIVW"
N1 = len(S1)
N2 = len(S2)
print("Cipher Text 1 : " )
print(S1)
print("Deciphered Text 1: ")
printString(S1.upper(), N1)
print 
("--------------------------------------------------------------------------------------
-------------")
print("Cipher Text 2 : " )
print(S2)
print("Decipher Text 2 : ")
printString(S2.upper(), N2
# Out:
#   File "<ipython-input-2-da6575f1dd96>", line 15
#     if S[i] != ' ':
#      ^
# IndentationError: expected an indented block
