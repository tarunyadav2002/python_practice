# %%
with open('CurrencyData.txt') as f:
    lines=f.readlines()
    
currencyDict = {}   
for line in lines:
    parsed = line.split("\t")
    currencyDict[parsed[0]]=parsed[1]
    
print(currencyDict) 
print("\n")
amount=int(input("enter the amount:\n"))
print("\n")
print("enter the name of the currency you want to convert this amount to?")
[print(item) for item in currencyDict.keys()]
print("\n")
currency=input("please enter one of these values")
print(f"{amount} INR is equal to {amount*float(currencyDict[currency])} {currency}")
# Out:
# {'Argentine Peso': '1.082486', 'Australian Dollar': '0.018550', 'Bahraini Dinar': '0.005070', 'Botswana Pula': '0.150021', 'Brazilian Real': '0.071503', 'British Pound': '0.010194', 'Bruneian Dollar': '0.018138', 'Bulgarian Lev': '0.022271', 'Canadian Dollar': '0.017646', 'Chilean Peso': '10.217291', 'Chinese Yuan Renminbi': '0.088767', 'Colombian Peso': '49.139547', 'Croatian Kuna': '0.086120', 'Czech Koruna': '0.300011', 'Danish Krone': '0.084852', 'Emirati Dirham': '0.049520', 'Euro': '0.011387', 'Hong Kong Dollar': '0.104544', 'Hungarian Forint': '4.094554', 'Icelandic Krona': '1.836912', 'Indonesian Rupiah': '190.990657', 'Iranian Rial': '567.667986', 'Israeli Shekel': '0.045168', 'Japanese Yen': '1.400552', 'Kazakhstani Tenge': '5.781072', 'Kuwaiti Dinar': '0.004124', 'Libyan Dinar': '0.018342', 'Malaysian Ringgit': '0.055332', 'Mauritian Rupee': '0.535786', 'Mexican Peso': '0.271974', 'Nepalese Rupee': '1.607500', 'New Zealand Dollar': '0.019545', 'Norwegian Krone': '0.121716', 'Omani Rial': '0.005185', 'Pakistani Rupee': '2.142873', 'Philippine Peso': '0.651738', 'Polish Zloty': '0.050894', 'Qatari Riyal': '0.049082', 'Romanian New Leu': '0.055488', 'Russian Ruble': '1.028137', 'Saudi Arabian Riyal': '0.050565', 'Singapore Dollar': '0.018138', 'South African Rand': '0.208330', 'South Korean Won': '15.022127', 'Sri Lankan Rupee': '2.495110', 'Swedish Krona': '0.116416', 'Swiss Franc': '0.012296', 'Taiwan New Dollar': '0.384662', 'Thai Baht': '0.409668', 'Trinidadian Dollar': '0.091559', 'Turkish Lira': '0.102006', 'US Dollar': '0.013484', 'Venezuelan Bolivar': '0.134673'}
#
#
# enter the amount:
# 50
#
#
# enter the name of the currency you want to convert this amount to?
# Argentine Peso
# Australian Dollar
# Bahraini Dinar
# Botswana Pula
# Brazilian Real
# British Pound
# Bruneian Dollar
# Bulgarian Lev
# Canadian Dollar
# Chilean Peso
# Chinese Yuan Renminbi
# Colombian Peso
# Croatian Kuna
# Czech Koruna
# Danish Krone
# Emirati Dirham
# Euro
# Hong Kong Dollar
# Hungarian Forint
# Icelandic Krona
# Indonesian Rupiah
# Iranian Rial
# Israeli Shekel
# Japanese Yen
# Kazakhstani Tenge
# Kuwaiti Dinar
# Libyan Dinar
# Malaysian Ringgit
# Mauritian Rupee
# Mexican Peso
# Nepalese Rupee
# New Zealand Dollar
# Norwegian Krone
# Omani Rial
# Pakistani Rupee
# Philippine Peso
# Polish Zloty
# Qatari Riyal
# Romanian New Leu
# Russian Ruble
# Saudi Arabian Riyal
# Singapore Dollar
# South African Rand
# South Korean Won
# Sri Lankan Rupee
# Swedish Krona
# Swiss Franc
# Taiwan New Dollar
# Thai Baht
# Trinidadian Dollar
# Turkish Lira
# US Dollar
# Venezuelan Bolivar
#
#
# please enter one of these valuesJapanese Yen
# 50 INR is equal to 70.0276 Japanese Yen

# %%
with open('CurrencyData.txt') as f:
    lines=f.readlines()
    
currencyDict = {}   
for line in lines:
    parsed = line.split("\t")
    currencyDict[parsed[0]]=parsed[1]
    
print(currencyDict) 
print("\n")
amount=int(input("enter the amount:\n"))
print("\n")
print("enter the name of the currency you want to convert this amount to?")
[print(item) for item in currencyDict.keys()]
print("\n")
currency=input("please enter one of these values")
print(f"{amount} INR is equal to {amount*float(currencyDict[currency])} {currency}")
# Out:
# {'Argentine Peso': '1.082486', 'Australian Dollar': '0.018550', 'Bahraini Dinar': '0.005070', 'Botswana Pula': '0.150021', 'Brazilian Real': '0.071503', 'British Pound': '0.010194', 'Bruneian Dollar': '0.018138', 'Bulgarian Lev': '0.022271', 'Canadian Dollar': '0.017646', 'Chilean Peso': '10.217291', 'Chinese Yuan Renminbi': '0.088767', 'Colombian Peso': '49.139547', 'Croatian Kuna': '0.086120', 'Czech Koruna': '0.300011', 'Danish Krone': '0.084852', 'Emirati Dirham': '0.049520', 'Euro': '0.011387', 'Hong Kong Dollar': '0.104544', 'Hungarian Forint': '4.094554', 'Icelandic Krona': '1.836912', 'Indonesian Rupiah': '190.990657', 'Iranian Rial': '567.667986', 'Israeli Shekel': '0.045168', 'Japanese Yen': '1.400552', 'Kazakhstani Tenge': '5.781072', 'Kuwaiti Dinar': '0.004124', 'Libyan Dinar': '0.018342', 'Malaysian Ringgit': '0.055332', 'Mauritian Rupee': '0.535786', 'Mexican Peso': '0.271974', 'Nepalese Rupee': '1.607500', 'New Zealand Dollar': '0.019545', 'Norwegian Krone': '0.121716', 'Omani Rial': '0.005185', 'Pakistani Rupee': '2.142873', 'Philippine Peso': '0.651738', 'Polish Zloty': '0.050894', 'Qatari Riyal': '0.049082', 'Romanian New Leu': '0.055488', 'Russian Ruble': '1.028137', 'Saudi Arabian Riyal': '0.050565', 'Singapore Dollar': '0.018138', 'South African Rand': '0.208330', 'South Korean Won': '15.022127', 'Sri Lankan Rupee': '2.495110', 'Swedish Krona': '0.116416', 'Swiss Franc': '0.012296', 'Taiwan New Dollar': '0.384662', 'Thai Baht': '0.409668', 'Trinidadian Dollar': '0.091559', 'Turkish Lira': '0.102006', 'US Dollar': '0.013484', 'Venezuelan Bolivar': '0.134673'}
#
#
# enter the amount:
# 100
#
#
# enter the name of the currency you want to convert this amount to?
# Argentine Peso
# Australian Dollar
# Bahraini Dinar
# Botswana Pula
# Brazilian Real
# British Pound
# Bruneian Dollar
# Bulgarian Lev
# Canadian Dollar
# Chilean Peso
# Chinese Yuan Renminbi
# Colombian Peso
# Croatian Kuna
# Czech Koruna
# Danish Krone
# Emirati Dirham
# Euro
# Hong Kong Dollar
# Hungarian Forint
# Icelandic Krona
# Indonesian Rupiah
# Iranian Rial
# Israeli Shekel
# Japanese Yen
# Kazakhstani Tenge
# Kuwaiti Dinar
# Libyan Dinar
# Malaysian Ringgit
# Mauritian Rupee
# Mexican Peso
# Nepalese Rupee
# New Zealand Dollar
# Norwegian Krone
# Omani Rial
# Pakistani Rupee
# Philippine Peso
# Polish Zloty
# Qatari Riyal
# Romanian New Leu
# Russian Ruble
# Saudi Arabian Riyal
# Singapore Dollar
# South African Rand
# South Korean Won
# Sri Lankan Rupee
# Swedish Krona
# Swiss Franc
# Taiwan New Dollar
# Thai Baht
# Trinidadian Dollar
# Turkish Lira
# US Dollar
# Venezuelan Bolivar
#
#
# please enter one of these valuesAustralian Dollar
# 100 INR is equal to 1.855 Australian Dollar
